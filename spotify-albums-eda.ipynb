# %% [markdown]
# <a href="https://www.kaggle.com/code/akshayaneesh5689/spotify-albums-eda?scriptVersionId=183240740" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <center><h2>Introduction</h2></center>

# %% [markdown]
# ![image.png](attachment:3d256304-e026-4e4e-add4-746e3d8ac30a.png)

# %% [markdown]
# <center><h3>Spotify App Description</h3></center>
# <p>Spotify is a popular music streaming service that allows users to access a vast library of songs, albums, and playlists from various artists around the world. Launched in 2008, Spotify offers both free and premium subscription plans, providing users with the ability to stream music online, download tracks for offline listening, and discover new music through personalized recommendations. The app is known for its user-friendly interface, curated playlists, and features such as collaborative playlists, podcasts, and integration with various social media platforms. Available on multiple devices, including smartphones, tablets, and desktops, Spotify has revolutionized the way people listen to and share music globally.</p>

# %% [markdown]
# <center><h3>Dataset Description</h3></center>
# The dataset used in this analysis comprises detailed information about tracks available on Spotify, focusing on their presence and performance across multiple streaming platforms.

# %% [markdown]
# <center><h2>Importing Libraries</h2></center>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %% [markdown]
# <center><h3>Loading dataset to the notebook</h3></center>

# %%
df = pd.read_csv("/kaggle/input/spotfy/Popular_Spotify_Songs.csv", encoding='latin1')

# %% [markdown]
# <center><h3>First 10 rows of the dataset</h3></center>

# %%
df.head(11)
# Out:
#                              track_name              artist(s)_name  \
# 0   Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                  LALA                 Myke Towers
# 2                               vampire              Olivia Rodrigo
# 3                          Cruel Summer                Taylor Swift
# 4                        WHERE SHE GOES                   Bad Bunny
# 5                              Sprinter           Dave, Central Cee
# 6                       Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                              Columbia                     Quevedo
# 8                              fukumean                       Gunna
# 9                       La Bebe - Remix       Peso Pluma, Yng Lvcas
# 10                            un x100to   Bad Bunny, Grupo Frontera
#
#     artist_count  released_year  released_month  released_day  \
# 0              2           2023               7            14
# ...

# %% [markdown]
# <center><h3>Last 5 rows of the dataset</h3></center>

# %%
df.tail(6)
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 947              The Great War        Taylor Swift             1
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 947           2022              10            21                  1274
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
# ...

# %% [markdown]
# <center><h3>Basic information on the dataset</h3></center>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# <center><h3>Shape of the dataset ( number of rows,number of columns )</h3></center>

# %%
df.shape
# Out:
# (953, 24)

# %% [markdown]
# <center><h3>Statistics about dataset</h3></center>

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# <center><h1>Data Cleaning</h1></center>

# %% [markdown]
# <center><h3>Checking for null values</h3></center>

# %%
df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# <center><h3>Removing columns having null values</h3></center>

# %%
cleaned_df=df.drop(["in_shazam_charts","key"],axis=1)
cleaned_df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  in_deezer_charts  \
# ...

# %%
cleaned_df.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# bpm                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %%
cleaned_df.shape
# Out:
# (953, 22)

# %% [markdown]
# <center><h3>Checking for duplicated values</h3></center>

# %%
cleaned_df.duplicated().sum()
# Out:
# 0

# %%
cleaned_df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'bpm', 'mode',
#        'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
#        'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %% [markdown]
# <center><h1>Data Exploration</h1></center>

# %% [markdown]
# <center><h3>Insights on number of songs released per year </h3></center>

# %%
plt.figure(figsize=(16,8))
sns.countplot(x="released_year",data=cleaned_df, order=cleaned_df["released_year"].value_counts().index[0:11],palette="magma")
# Out:
# <Axes: xlabel='released_year', ylabel='count'>

# %% [markdown]
# From this countplot, it is clear that **most songs were released in 2022**. Moreover, there is a **significant difference in the number of songs released between 2022 and 2023**. **In 2020 and 2019, the release counts were relatively stable**. In my opinion, after the COVID-19 pandemic, more people gained access to smartphones and computers worldwide. Consequently, many individuals began using entertainment applications like Spotify and YouTube Music, leading to exponential growth in the entertainment industry. This surge likely encouraged more artists to release their music on Spotify. What do you think?

# %%
cleaned_df["released_year"].value_counts().index[0:11]
# Out:
# Index([2022, 2023, 2021, 2020, 2019, 2017, 2016, 2014, 2013, 2015, 2018], dtype='int64', name='released_year')

# %%
value_counts = cleaned_df['released_year'].value_counts()
top_years = value_counts.head(11)
top_years_df = top_years.reset_index()
top_years_df.columns = ['Year', 'Count']
top_years_df
# Out:
#     Year  Count
# 0   2022    402
# 1   2023    175
# 2   2021    119
# 3   2020     37
# 4   2019     36
# 5   2017     23
# 6   2016     18
# 7   2014     13
# 8   2013     13
# 9   2015     11
# 10  2018     10

# %% [markdown]
# The above table confirms the count plot.

# %% [markdown]
# <center><h3>Insights on artist count</h3></center>

# %%
sns.displot(cleaned_df["artist_count"],bins=7)

# %% [markdown]
# From this count plot, it is clear that **most of the content released on Spotify consists of solo performances**. This suggests that solo performances might be in high demand in the industry. What do you think?

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  bpm                   953 non-null    int64
#  14  mode                  953 non-null    object
# ...

# %% [markdown]
# <center><h3>Insights on instrumentalness and energy</h3></center>

# %%
cleaned_df.replace([np.inf, -np.inf], np.nan, inplace=True)
cleaned_df = cleaned_df.dropna(subset=['instrumentalness_%', 'energy_%', 'artist_count'])

# %%
sns.jointplot(x="instrumentalness_%",y="energy_%",hue="artist_count", data=cleaned_df, palette="hls")

# %% [markdown]
# From this jointplot, it is evident that solo performances generally have high instrumentalness and energy. Additionally, most of the tracks tend to cluster around the zero mark.

# %% [markdown]
# <center><h3>Insights on energy and speechiness</h3></center>

# %%
sns.jointplot(x="speechiness_%",y="energy_%",hue="artist_count", data=cleaned_df,palette="hls")

# %%
cleaned_df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'bpm', 'mode',
#        'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
#        'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %% [markdown]
# <center><h3>Insights on spotify playlists and artist count</h3></center>

# %%
plt.figure(figsize=(8,6))
sns.stripplot(y="in_spotify_playlists", x="artist_count", data=cleaned_df, hue="released_year")
# Out:
# <Axes: xlabel='artist_count', ylabel='in_spotify_playlists'>

# %% [markdown]
# <center><h1>Conclusion</h1></center>
#
# In conclusion, our analysis of the Spotify dataset has provided valuable insights into the characteristics and trends of music released on the platform. The data shows a significant increase in song releases post-pandemic, likely driven by the wider accessibility of smartphones and entertainment applications. Most of the content on Spotify consists of solo performances, which appear to be in high demand. The jointplot analysis revealed that solo tracks often have high instrumentalness and energy, while a substantial number of tracks cluster around zero in these attributes. These findings suggest a diverse range of music preferences among Spotify users, with a notable lean towards energetic and instrumental solo performances. This analysis not only highlights current trends but also offers a foundation for future research into the evolving dynamics of the music streaming industry.
